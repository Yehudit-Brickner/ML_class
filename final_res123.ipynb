# %% [markdown]
# # ML class final project part3
# ##  Almog Shor
# ## Yehudit Brickner

# %%
import os
import cv2 
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns
import time
import pickle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings(action='ignore', category=UserWarning)

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OutputCodeClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC

from sklearn.neighbors import KNeighborsClassifier

from sklearn.ensemble import AdaBoostClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.linear_model import LogisticRegression

# %%
# function to represent the confusion matrix nicely
def Confusion_Matrix(cf_matrix):
    plt.figure(figsize=(6,6))
    sns.heatmap(cf_matrix, annot=True, fmt='', cmap='Greens')

# %%
test_data1 = pd.read_csv('final_test_data_small_hist.csv')
del test_data1['path']
del test_data1['class_name']
ball_type = [0,2,9,11]
test_data1 = test_data1.loc[test_data1['class_number'].isin(ball_type)]
test_data1.shape
# Out:
# (383, 773)

# %%
X1 = test_data1.iloc[:,2:6]
X2 = test_data1.iloc[:,5:] 
X3 = test_data1.drop(['class_number'], axis=1)

y = test_data1['class_number']


# pca1=PCA(n_components=100)
# X4=pca1.fit_transform(X3)
# X4.shape
X4 = pd.read_csv('df_X4_final_test.csv')
X4 = X4.drop(['class_number'], axis=1)
X4.shape
# Out:
# (383, 100)

# %%
results=[]

# %%
svm1 = pickle.load(open('svm1.sav', 'rb'))
neigh1 = pickle.load(open('knn1.sav', 'rb'))
ada1 = pickle.load(open('ada1.sav', 'rb'))
RF1 = pickle.load(open('RF1.sav', 'rb'))
LR1 = pickle.load(open('LR1.sav', 'rb'))


svm2 = pickle.load(open('svm2.sav', 'rb'))
neigh2 = pickle.load(open('knn2.sav', 'rb'))
ada2 = pickle.load(open('ada2.sav', 'rb'))
RF2= pickle.load(open('RF2.sav', 'rb'))
LR2 = pickle.load(open('LR2.sav', 'rb'))


svm3 = pickle.load(open('svm3.sav', 'rb'))
neigh3 = pickle.load(open('knn3.sav', 'rb'))
ada3 = pickle.load(open('ada3.sav', 'rb'))
RF3 = pickle.load(open('RF3.sav', 'rb'))
LR3 = pickle.load(open('LR3.sav', 'rb'))


svm4 = pickle.load(open('svm4.sav', 'rb'))
neigh4 = pickle.load(open('knn4.sav', 'rb'))
ada4 = pickle.load(open('ada4.sav', 'rb'))
RF4 = pickle.load(open('RF4.sav', 'rb'))
LR4 = pickle.load(open('LR4.sav', 'rb'))


svm5 = pickle.load(open('svm5.sav', 'rb'))
neigh5 = pickle.load(open('knn5.sav', 'rb'))
ada5 = pickle.load(open('ada5.sav', 'rb'))
RF5 = pickle.load(open('RF5.sav', 'rb'))
LR5 = pickle.load(open('LR5.sav', 'rb'))



svm6 = pickle.load(open('svm6.sav', 'rb'))
neigh6 = pickle.load(open('knn6.sav', 'rb'))
ada6 = pickle.load(open('ada6.sav', 'rb'))
RF6 = pickle.load(open('RF6.sav', 'rb'))
LR6 = pickle.load(open('LR6.sav', 'rb'))


svm7 = pickle.load(open('svm7.sav', 'rb'))
neigh7 = pickle.load(open('knn7.sav', 'rb'))
ada7 = pickle.load(open('ada7.sav', 'rb'))
RF7 = pickle.load(open('RF7.sav', 'rb'))
LR7 = pickle.load(open('LR7.sav', 'rb'))


svm8 = pickle.load(open('svm8.sav', 'rb'))
neigh8 = pickle.load(open('knn8.sav', 'rb'))
ada8 = pickle.load(open('ada8.sav', 'rb'))
RF8 = pickle.load(open('RF8.sav', 'rb'))
LR8 = pickle.load(open('LR8.sav', 'rb'))


svm9 = pickle.load(open('svm9.sav', 'rb'))
neigh9 = pickle.load(open('knn9.sav', 'rb'))
ada9 = pickle.load(open('ada9.sav', 'rb'))
RF9 = pickle.load(open('RF9.sav', 'rb'))
LR9 = pickle.load(open('LR9.sav', 'rb'))

# %%
print("SVM")
pred_svm = svm1.predict(X1)
Confusion_Matrix(confusion_matrix(y,pred_svm))
print(classification_report(y, pred_svm))
print(round(np.sum([y==pred_svm])/len(y),4)*100,"%")
results.append(['lines and circles', 'SVM',round(np.sum([y==pred_svm])/len(y),4)*100])

print('\nKNN')
pred_knn = neigh1.predict(X1)
Confusion_Matrix(confusion_matrix(y,pred_knn))
print(classification_report(y, pred_knn))
print(round(np.sum([y==pred_knn])/len(y),4)*100,"%")
results.append(['lines and circles', 'KNN',round(np.sum([y==pred_knn])/len(y),4)*100])

print('\nAdaboost')
pred_ada = ada1.predict(X1)
Confusion_Matrix(confusion_matrix(y,pred_ada))
print(classification_report(y, pred_ada))
print(round(np.sum([y==pred_ada])/len(y),4)*100,"%")
results.append(['lines and circles', 'Adaboost',round(np.sum([y==pred_ada])/len(y),4)*100])


print('\nRandom Forest')
pred_rf = RF1.predict(X1)
Confusion_Matrix(confusion_matrix(y,pred_rf))
print(classification_report(y, pred_rf))
print(round(np.sum([y==pred_rf])/len(y),4)*100,"%")
results.append(['lines and circles', 'Random Forest',round(np.sum([y==pred_rf])/len(y),4)*100])


print("\nLogistic Regression")
pred_lr = LR1.predict(X1)
Confusion_Matrix(confusion_matrix(y,pred_lr))
print(classification_report(y, pred_lr))
print(round(np.sum([y==pred_lr])/len(y),4)*100,"%")
results.append(['lines and circles', 'Logistic Regression',round(np.sum([y==pred_lr])/len(y),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.40      0.24      0.30        96
#            2       0.26      0.88      0.40        85
#            9       0.58      0.07      0.13        97
#           11       0.45      0.10      0.16       105
#
#     accuracy                           0.30       383
#    macro avg       0.42      0.32      0.25       383
# weighted avg       0.43      0.30      0.24       383
#
# 30.03 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.18      0.06      0.09        96
#            2       0.29      0.36      0.32        85
#            9       0.24      0.61      0.35        97
#           11       0.00      0.00      0.00       105
#
#     accuracy                           0.25       383
#    macro avg       0.18      0.26      0.19       383
# weighted avg       0.17      0.25      0.18       383
#
# 25.069999999999997 %
#
# Adaboost
# ...

# %%
print("SVM")
pred_svm = svm2.predict(X2)
Confusion_Matrix(confusion_matrix(y,pred_svm))
print(classification_report(y, pred_svm))
print(round(np.sum([y==pred_svm])/len(y),4)*100,"%")
results.append(['histogram', 'SVM',round(np.sum([y==pred_svm])/len(y),4)*100])

print('\nKNN')
pred_knn = neigh2.predict(X2)
Confusion_Matrix(confusion_matrix(y,pred_knn))
print(classification_report(y, pred_knn))
print(round(np.sum([y==pred_knn])/len(y),4)*100,"%")
results.append(['histogram', 'KNN',round(np.sum([y==pred_knn])/len(y),4)*100])

print('\nAdaboost')
pred_ada = ada2.predict(X2)
Confusion_Matrix(confusion_matrix(y,pred_ada))
print(classification_report(y, pred_ada))
print(round(np.sum([y==pred_ada])/len(y),4)*100,"%")
results.append(['histogram', 'Adaboost',round(np.sum([y==pred_ada])/len(y),4)*100])


print('\nRandom Forest')
pred_rf = RF2.predict(X2)
Confusion_Matrix(confusion_matrix(y,pred_rf))
print(classification_report(y, pred_rf))
print(round(np.sum([y==pred_rf])/len(y),4)*100,"%")
results.append(['histogram', 'Random Forest',round(np.sum([y==pred_rf])/len(y),4)*100])


print("\nLogistic Regression")
pred_lr = LR2.predict(X2)
Confusion_Matrix(confusion_matrix(y,pred_lr))
print(classification_report(y, pred_lr))
print(round(np.sum([y==pred_lr])/len(y),4)*100,"%")
results.append(['histogram', 'Logistic Regression',round(np.sum([y==pred_lr])/len(y),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.41      0.57      0.48        96
#            2       0.45      0.33      0.38        85
#            9       0.45      0.34      0.39        97
#           11       0.47      0.51      0.49       105
#
#     accuracy                           0.44       383
#    macro avg       0.45      0.44      0.44       383
# weighted avg       0.45      0.44      0.44       383
#
# 44.39 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.42      0.69      0.52        96
#            2       0.44      0.45      0.44        85
#            9       0.59      0.34      0.43        97
#           11       0.67      0.52      0.59       105
#
#     accuracy                           0.50       383
#    macro avg       0.53      0.50      0.50       383
# weighted avg       0.54      0.50      0.50       383
#
# 50.129999999999995 %
#
# Adaboost
# ...

# %%
print("SVM")
pred_svm = svm3.predict(X3)
Confusion_Matrix(confusion_matrix(y,pred_svm))
print(classification_report(y, pred_svm))
print(round(np.sum([y==pred_svm])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram', 'SVM',round(np.sum([y==pred_svm])/len(y),4)*100])

print('\nKNN')
pred_knn = neigh3.predict(X3)
Confusion_Matrix(confusion_matrix(y,pred_knn))
print(classification_report(y, pred_knn))
print(round(np.sum([y==pred_knn])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram', 'KNN',round(np.sum([y==pred_knn])/len(y),4)*100])

print('\nAdaboost')
pred_ada = ada3.predict(X3)
Confusion_Matrix(confusion_matrix(y,pred_ada))
print(classification_report(y, pred_ada))
print(round(np.sum([y==pred_ada])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram', 'Adaboost',round(np.sum([y==pred_ada])/len(y),4)*100])


print('\nRandom Forest')
pred_rf = RF3.predict(X3)
Confusion_Matrix(confusion_matrix(y,pred_rf))
print(classification_report(y, pred_rf))
print(round(np.sum([y==pred_rf])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram', 'Random Forest',round(np.sum([y==pred_rf])/len(y),4)*100])


print("\nLogistic Regression")
pred_lr = LR3.predict(X3)
Confusion_Matrix(confusion_matrix(y,pred_lr))
print(classification_report(y, pred_lr))
print(round(np.sum([y==pred_lr])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram', 'Logistic Regression',round(np.sum([y==pred_lr])/len(y),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.49      0.44      0.46        96
#            2       0.42      0.49      0.45        85
#            9       0.42      0.32      0.36        97
#           11       0.49      0.57      0.53       105
#
#     accuracy                           0.46       383
#    macro avg       0.45      0.46      0.45       383
# weighted avg       0.46      0.46      0.45       383
#
# 45.69 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.43      0.70      0.53        96
#            2       0.43      0.45      0.44        85
#            9       0.62      0.34      0.44        97
#           11       0.69      0.56      0.62       105
#
#     accuracy                           0.51       383
#    macro avg       0.54      0.51      0.51       383
# weighted avg       0.55      0.51      0.51       383
#
# 51.44 %
#
# Adaboost
# ...

# %%
print("SVM")
pred_svm = svm4.predict(X4)
Confusion_Matrix(confusion_matrix(y,pred_svm))
print(classification_report(y, pred_svm))
print(round(np.sum([y==pred_svm])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram PCA 100', 'SVM',round(np.sum([y==pred_svm])/len(y),4)*100])

print('\nKNN')
pred_knn = neigh4.predict(X4)
Confusion_Matrix(confusion_matrix(y,pred_knn))
print(classification_report(y, pred_knn))
print(round(np.sum([y==pred_knn])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram PCA 100', 'KNN',round(np.sum([y==pred_knn])/len(y),4)*100])

print('\nAdaboost')
pred_ada = ada4.predict(X4)
Confusion_Matrix(confusion_matrix(y,pred_ada))
print(classification_report(y, pred_ada))
print(round(np.sum([y==pred_ada])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram PCA 100', 'Adaboost',round(np.sum([y==pred_ada])/len(y),4)*100])


print('\nRandom Forest')
pred_rf = RF4.predict(X4)
Confusion_Matrix(confusion_matrix(y,pred_rf))
print(classification_report(y, pred_rf))
print(round(np.sum([y==pred_rf])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram PCA 100', 'Random Forest',round(np.sum([y==pred_rf])/len(y),4)*100])


print("\nLogistic Regression")
pred_lr = LR4.predict(X4)
Confusion_Matrix(confusion_matrix(y,pred_lr))
print(classification_report(y, pred_lr))
print(round(np.sum([y==pred_lr])/len(y),4)*100,"%")
results.append(['lines, circle, and histogram PCA 100', 'Logistic Regression',round(np.sum([y==pred_lr])/len(y),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.43      0.24      0.31        96
#            2       0.24      0.53      0.33        85
#            9       0.41      0.24      0.30        97
#           11       0.31      0.26      0.28       105
#
#     accuracy                           0.31       383
#    macro avg       0.35      0.32      0.31       383
# weighted avg       0.35      0.31      0.30       383
#
# 30.81 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.52        96
#            2       0.47      0.51      0.49        85
#            9       0.53      0.44      0.48        97
#           11       0.62      0.59      0.60       105
#
#     accuracy                           0.53       383
#    macro avg       0.53      0.53      0.52       383
# weighted avg       0.53      0.53      0.53       383
#
# 52.739999999999995 %
#
# Adaboost
# ...

# %%
# cols = ["df_type","classifier","accuracy"]
# df = pd.DataFrame(results, columns=cols)
# df

# %%
test_data_edge1 = pd.read_csv('df_X5_final_test.csv')
test_data_edge2 = pd.read_csv('df_X8_final_test.csv')
print(test_data_edge1.shape , test_data_edge2.shape)

test_data_edge2 = test_data_edge2.dropna()
test_data_edge1 = test_data_edge1.dropna()
print(test_data_edge1.shape,test_data_edge2.shape)
# del test_data2['path']
# del test_data2['class_name']
# ball_type = [0,2,9,11]
# test_data2 = test_data2.loc[test_data2['class_number'].isin(ball_type)]
# test_data2.shape
# Out:
# (388, 101) (388, 401)
# (388, 101) (388, 401)

# %%
y5 = test_data_edge1['class_number']
X5 = test_data_edge1.drop(['class_number'], axis=1)

y8 = test_data_edge2['class_number']
X8 = test_data_edge2.drop(['class_number'], axis=1)
# X = X.dropna()
# print(X.shape)
# pca_edge1 = PCA(n_components=100)
# X5 = pca_edge1.fit_transform(X)
# print(X5.shape)
# pca_edge2 = PCA(n_components=400)
# X8 = pca_edge1.fit_transform(X)
# print(X8.shape)

# %%
print("SVM")
pred_svm = svm5.predict(X5)
Confusion_Matrix(confusion_matrix(y5,pred_svm))
print(classification_report(y5, pred_svm))
print(round(np.sum([y5==pred_svm])/len(y5),4)*100,"%")
results.append(['edges PCA 100', 'SVM',round(np.sum([y5==pred_svm])/len(y5),4)*100])

print('\nKNN')
pred_knn = neigh5.predict(X5)
Confusion_Matrix(confusion_matrix(y5,pred_knn))
print(classification_report(y5, pred_knn))
print(round(np.sum([y5==pred_knn])/len(y5),4)*100,"%")
results.append(['edges PCA 100', 'KNN',round(np.sum([y5==pred_knn])/len(y5),4)*100])

print('\nAdaboost')
pred_ada = ada5.predict(X5)
Confusion_Matrix(confusion_matrix(y5,pred_ada))
print(classification_report(y5, pred_ada))
print(round(np.sum([y5==pred_ada])/len(y5),4)*100,"%")
results.append(['edges PCA 100', 'Adaboost',round(np.sum([y5==pred_ada])/len(y5),4)*100])


print('\nRandom Forest')
pred_rf = RF5.predict(X5)
Confusion_Matrix(confusion_matrix(y5,pred_rf))
print(classification_report(y5, pred_rf))
print(round(np.sum([y5==pred_rf])/len(y5),4)*100,"%")
results.append(['edges PCA 100', 'Random Forest',round(np.sum([y5==pred_rf])/len(y5),4)*100])


print("\nLogistic Regression")
pred_lr = LR5.predict(X5)
Confusion_Matrix(confusion_matrix(y5,pred_lr))
print(classification_report(y5, pred_lr))
print(round(np.sum([y5==pred_lr])/len(y5),4)*100,"%")
results.append(['edges PCA 100', 'Logistic Regression',round(np.sum([y5==pred_lr])/len(y5),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.28      0.25      0.26        96
#            2       0.41      0.36      0.38        86
#            9       0.31      0.30      0.30        98
#           11       0.37      0.45      0.41       108
#
#     accuracy                           0.34       388
#    macro avg       0.34      0.34      0.34       388
# weighted avg       0.34      0.34      0.34       388
#
# 34.28 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.53      0.52      0.53        96
#            2       0.50      0.43      0.46        86
#            9       0.48      0.61      0.54        98
#           11       0.62      0.56      0.59       108
#
#     accuracy                           0.53       388
#    macro avg       0.54      0.53      0.53       388
# weighted avg       0.54      0.53      0.53       388
#
# 53.349999999999994 %
#
# Adaboost
# ...

# %%
print("SVM")
pred_svm = svm8.predict(X8)
Confusion_Matrix(confusion_matrix(y8,pred_svm))
print(classification_report(y8, pred_svm))
print(round(np.sum([y8==pred_svm])/len(y8),4)*100,"%")
results.append(['edges PCA 400', 'SVM',round(np.sum([y8==pred_svm])/len(y8),4)*100])

print('\nKNN')
pred_knn = neigh8.predict(X8)
Confusion_Matrix(confusion_matrix(y8,pred_knn))
print(classification_report(y8, pred_knn))
print(round(np.sum([y8==pred_knn])/len(y8),4)*100,"%")
results.append(['edges PCA 400', 'KNN',round(np.sum([y8==pred_knn])/len(y8),4)*100])

print('\nAdaboost')
pred_ada = ada8.predict(X8)
Confusion_Matrix(confusion_matrix(y8,pred_ada))
print(classification_report(y8, pred_ada))
print(round(np.sum([y8==pred_ada])/len(y8),4)*100,"%")
results.append(['edges PCA 400', 'Adaboost',round(np.sum([y8==pred_ada])/len(y8),4)*100])


print('\nRandom Forest')
pred_rf = RF8.predict(X8)
Confusion_Matrix(confusion_matrix(y8,pred_rf))
print(classification_report(y8, pred_rf))
print(round(np.sum([y8==pred_rf])/len(y8),4)*100,"%")
results.append(['edges PCA 400', 'Random Forest',round(np.sum([y8==pred_rf])/len(y8),4)*100])


print("\nLogistic Regression")
pred_lr = LR8.predict(X8)
Confusion_Matrix(confusion_matrix(y8,pred_lr))
print(classification_report(y8, pred_lr))
print(round(np.sum([y8==pred_lr])/len(y8),4)*100,"%")
results.append(['edges PCA 400', 'Logistic Regression',round(np.sum([y8==pred_lr])/len(y8),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.41      0.41      0.41        96
#            2       0.38      0.33      0.35        86
#            9       0.36      0.39      0.37        98
#           11       0.48      0.49      0.48       108
#
#     accuracy                           0.41       388
#    macro avg       0.40      0.40      0.40       388
# weighted avg       0.41      0.41      0.41       388
#
# 40.72 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.44      0.40      0.42        96
#            2       0.36      0.17      0.23        86
#            9       0.41      0.58      0.48        98
#           11       0.45      0.50      0.47       108
#
#     accuracy                           0.42       388
#    macro avg       0.41      0.41      0.40       388
# weighted avg       0.42      0.42      0.41       388
#
# 42.27 %
#
# Adaboost
# ...

# %%
# test_data3 = pd.read_csv('final_test_data_image.csv')
# del test_data3['path']
# del test_data3['class_name']
# ball_type = [0,2,9,11]
# test_data3 = test_data3.loc[test_data3['class_number'].isin(ball_type)]
# test_data3.shape

# %%
# y = test_data3['class_number']
# X = test_data3.drop(['class_number'], axis=1)
# X = X.dropna()
# X.shape

# %%
# pca_image1 = PCA(n_components=100)
# X6 = pca_image1.transform(X)
# print(X6.shape)

# pca_image2 = PCA(n_components=200)
# X7 = pca_image2.transform(X)
# print(X6.shape)

# pca_image3 = PCA(n_components=500)
# X9 = pca_image3.transform(X)
# print(X9.shape)

X6 = pd.read_csv('df_X6_final_test.csv')
y6 = X6['class_number']
X6 = X6.drop(['class_number'], axis=1)
X6.shape
# Out:
# (383, 100)

# %%
print("SVM")
pred_svm = svm6.predict(X6)
Confusion_Matrix(confusion_matrix(y6,pred_svm))
print(classification_report(y6, pred_svm))
print(round(np.sum([y6==pred_svm])/len(y6),4)*100,"%")
results.append(['image PCA 100', 'SVM',round(np.sum([y6==pred_svm])/len(y6),4)*100])

print('\nKNN')
pred_knn = neigh6.predict(X6)
Confusion_Matrix(confusion_matrix(y6,pred_knn))
print(classification_report(y6, pred_knn))
print(round(np.sum([y6==pred_knn])/len(y6),4)*100,"%")
results.append(['image PCA 100', 'KNN',round(np.sum([y6==pred_knn])/len(y6),4)*100])

print('\nAdaboost')
pred_ada = ada6.predict(X6)
Confusion_Matrix(confusion_matrix(y6,pred_ada))
print(classification_report(y6, pred_ada))
print(round(np.sum([y6==pred_ada])/len(y6),4)*100,"%")
results.append(['image PCA 100', 'Adaboost',round(np.sum([y6==pred_ada])/len(y6),4)*100])


print('\nRandom Forest')
pred_rf = RF6.predict(X6)
Confusion_Matrix(confusion_matrix(y6,pred_rf))
print(classification_report(y6, pred_rf))
print(round(np.sum([y6==pred_rf])/len(y6),4)*100,"%")
results.append(['image PCA 100', 'Random Forest',round(np.sum([y6==pred_rf])/len(y6),4)*100])


print("\nLogistic Regression")
pred_lr = LR6.predict(X6)
Confusion_Matrix(confusion_matrix(y6,pred_lr))
print(classification_report(y6, pred_lr))
print(round(np.sum([y6==pred_lr])/len(y6),4)*100,"%")
results.append(['image PCA 100', 'Logistic Regression',round(np.sum([y6==pred_lr])/len(y6),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.51      0.47      0.49        96
#            2       0.42      0.42      0.42        85
#            9       0.32      0.28      0.30        97
#           11       0.59      0.70      0.64       105
#
#     accuracy                           0.48       383
#    macro avg       0.46      0.47      0.46       383
# weighted avg       0.46      0.48      0.47       383
#
# 47.52 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        96
#            2       0.57      0.53      0.55        85
#            9       0.60      0.52      0.55        97
#           11       0.68      0.80      0.74       105
#
#     accuracy                           0.62       383
#    macro avg       0.62      0.62      0.61       383
# weighted avg       0.62      0.62      0.62       383
#
# 62.4 %
#
# Adaboost
# ...

# %%
X7 = pd.read_csv('df_X7_final_test.csv')
y7 = X7['class_number']
X7 = X7.drop(['class_number'], axis=1)
X7.shape
# Out:
# (383, 200)

# %%
print("SVM")
pred_svm = svm7.predict(X7)
Confusion_Matrix(confusion_matrix(y7,pred_svm))
print(classification_report(y7, pred_svm))
print(round(np.sum([y7==pred_svm])/len(y7),4)*100,"%")
results.append(['image PCA 200', 'SVM',round(np.sum([y7==pred_svm])/len(y7),4)*100])

print('\nKNN')
pred_knn = neigh7.predict(X7)
Confusion_Matrix(confusion_matrix(y7,pred_knn))
print(classification_report(y7, pred_knn))
print(round(np.sum([y7==pred_knn])/len(y7),4)*100,"%")
results.append(['image PCA 200', 'KNN',round(np.sum([y7==pred_knn])/len(y7),4)*100])

print('\nAdaboost')
pred_ada = ada7.predict(X7)
Confusion_Matrix(confusion_matrix(y7,pred_ada))
print(classification_report(y7, pred_ada))
print(round(np.sum([y7==pred_ada])/len(y7),4)*100,"%")
results.append(['image PCA 200', 'Adaboost',round(np.sum([y7==pred_ada])/len(y7),4)*100])


print('\nRandom Forest')
pred_rf = RF7.predict(X7)
Confusion_Matrix(confusion_matrix(y7,pred_rf))
print(classification_report(y7, pred_rf))
print(round(np.sum([y7==pred_rf])/len(y7),4)*100,"%")
results.append(['image PCA 200', 'Random Forest',round(np.sum([y7==pred_rf])/len(y7),4)*100])


print("\nLogistic Regression")
pred_lr = LR7.predict(X7)
Confusion_Matrix(confusion_matrix(y7,pred_lr))
print(classification_report(y7, pred_lr))
print(round(np.sum([y7==pred_lr])/len(y7),4)*100,"%")
results.append(['image PCA 200', 'Logistic Regression',round(np.sum([y7==pred_lr])/len(y7),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.42      0.44      0.43        96
#            2       0.47      0.55      0.51        85
#            9       0.48      0.40      0.44        97
#           11       0.67      0.65      0.66       105
#
#     accuracy                           0.51       383
#    macro avg       0.51      0.51      0.51       383
# weighted avg       0.51      0.51      0.51       383
#
# 51.17 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.63        96
#            2       0.59      0.56      0.58        85
#            9       0.59      0.49      0.54        97
#           11       0.68      0.78      0.73       105
#
#     accuracy                           0.63       383
#    macro avg       0.62      0.62      0.62       383
# weighted avg       0.62      0.63      0.62       383
#
# 62.660000000000004 %
#
# Adaboost
# ...

# %%
X9 = pd.read_csv('df_X9_final_test.csv')
y9 = X9['class_number']
X9 = X9.drop(['class_number'], axis=1)
X9.shape
# Out:
# (383, 500)

# %%
print("SVM")
pred_svm = svm9.predict(X9)
Confusion_Matrix(confusion_matrix(y9,pred_svm))
print(classification_report(y9, pred_svm))
print(round(np.sum([y9==pred_svm])/len(y9),4)*100,"%")
results.append(['image PCA 500', 'SVM',round(np.sum([y9==pred_svm])/len(y9),4)*100])

print('\nKNN')
pred_knn = neigh9.predict(X9)
Confusion_Matrix(confusion_matrix(y9,pred_knn))
print(classification_report(y9, pred_knn))
print(round(np.sum([y9==pred_knn])/len(y9),4)*100,"%")
results.append(['image PCA 500', 'KNN',round(np.sum([y9==pred_knn])/len(y9),4)*100])

print('\nAdaboost')
pred_ada = ada9.predict(X9)
Confusion_Matrix(confusion_matrix(y9,pred_ada))
print(classification_report(y9, pred_ada))
print(round(np.sum([y9==pred_ada])/len(y9),4)*100,"%")
results.append(['image PCA 500', 'Adaboost',round(np.sum([y9==pred_ada])/len(y9),4)*100])


print('\nRandom Forest')
pred_rf = RF9.predict(X9)
Confusion_Matrix(confusion_matrix(y9,pred_rf))
print(classification_report(y9, pred_rf))
print(round(np.sum([y9==pred_rf])/len(y9),4)*100,"%")
results.append(['image PCA 500', 'Random Forest',round(np.sum([y9==pred_rf])/len(y9),4)*100])


print("\nLogistic Regression")
pred_lr = LR9.predict(X9)
Confusion_Matrix(confusion_matrix(y9,pred_lr))
print(classification_report(y9, pred_lr))
print(round(np.sum([y9==pred_lr])/len(y9),4)*100,"%")
results.append(['image PCA 500', 'Logistic Regression',round(np.sum([y9==pred_lr])/len(y9),4)*100])
# Out:
# SVM
#               precision    recall  f1-score   support
#
#            0       0.59      0.50      0.54        96
#            2       0.55      0.62      0.58        85
#            9       0.55      0.49      0.52        97
#           11       0.62      0.70      0.65       105
#
#     accuracy                           0.58       383
#    macro avg       0.58      0.58      0.58       383
# weighted avg       0.58      0.58      0.58       383
#
# 57.96 %
#
# KNN
#               precision    recall  f1-score   support
#
#            0       0.62      0.58      0.60        96
#            2       0.57      0.54      0.55        85
#            9       0.55      0.48      0.51        97
#           11       0.67      0.80      0.73       105
#
#     accuracy                           0.61       383
#    macro avg       0.60      0.60      0.60       383
# weighted avg       0.60      0.61      0.60       383
#
# 60.84 %
#
# Adaboost
# ...

# %%
cols = ["df_type","classifier","accuracy"]
df = pd.DataFrame(results, columns=cols)
df
# Out:
#                                  df_type           classifier  accuracy
# 0                      lines and circles                  SVM     30.03
# 1                      lines and circles                  KNN     25.07
# 2                      lines and circles             Adaboost     24.28
# 3                      lines and circles        Random Forest     24.80
# 4                      lines and circles  Logistic Regression     35.25
# 5                              histogram                  SVM     44.39
# 6                              histogram                  KNN     50.13
# 7                              histogram             Adaboost     52.22
# 8                              histogram        Random Forest     61.62
# 9                              histogram  Logistic Regression     53.26
# 10          lines, circle, and histogram                  SVM     45.69
# 11          lines, circle, and histogram                  KNN     51.44
# ...

# %%
df2=df.sort_values(by=['classifier','accuracy'])
df2
# Out:
#                                  df_type           classifier  accuracy
# 2                      lines and circles             Adaboost     24.28
# 27                         edges PCA 400             Adaboost     42.27
# 22                         edges PCA 100             Adaboost     45.88
# 17  lines, circle, and histogram PCA 100             Adaboost     46.21
# 7                              histogram             Adaboost     52.22
# 32                         image PCA 100             Adaboost     54.05
# 42                         image PCA 500             Adaboost     55.09
# 12          lines, circle, and histogram             Adaboost     56.92
# 37                         image PCA 200             Adaboost     57.96
# 1                      lines and circles                  KNN     25.07
# 26                         edges PCA 400                  KNN     42.27
# 6                              histogram                  KNN     50.13
# ...

# %%
df3=df.sort_values(by=['accuracy'])
df3
# Out:
#                                  df_type           classifier  accuracy
# 2                      lines and circles             Adaboost     24.28
# 3                      lines and circles        Random Forest     24.80
# 1                      lines and circles                  KNN     25.07
# 0                      lines and circles                  SVM     30.03
# 15  lines, circle, and histogram PCA 100                  SVM     30.81
# 20                         edges PCA 100                  SVM     34.28
# 4                      lines and circles  Logistic Regression     35.25
# 28                         edges PCA 400        Random Forest     39.18
# 25                         edges PCA 400                  SVM     40.72
# 29                         edges PCA 400  Logistic Regression     41.24
# 27                         edges PCA 400             Adaboost     42.27
# 26                         edges PCA 400                  KNN     42.27
# ...
